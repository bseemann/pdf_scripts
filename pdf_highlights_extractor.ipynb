# %% [markdown]
# Execute a célula abaixo antes de iniciar, pois ela instalará uma dependência obrigatória para a execução do código de extração do texto selecionado e comentários do(s) PDF(s).

# %%
# !pip install PyMuPDF
# Out:
# Collecting PyMuPDF
#   Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Downloading pymupdf-1.26.7-cp310-abi3-manylinux_2_28_x86_64.whl (24.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 72.7 MB/s eta 0:00:00
# Installing collected packages: PyMuPDF
# Successfully installed PyMuPDF-1.26.7

# %%
import fitz
import io
from tabulate import tabulate
from google.colab import auth
import google.auth
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from googleapiclient.http import MediaIoBaseDownload,MediaFileUpload

# %% [markdown]
# Na célula seguinte, você deve colocar o id da pasta do Google Drive onde estão os arquivos PDFs. Note que o id é o valor que aparece na URL: https://drive.google.com/drive/folders/ID

# %%
drive_id = ""

# %%
escopo = [
        "https://www.googleapis.com/auth/drive.appdata",
        "https://www.googleapis.com/auth/drive.file",
        "https://www.googleapis.com/auth/drive"
    ]
auth.authenticate_user()
creds, _ = google.auth.default(scopes=escopo)

servico_drive = build("drive", "v3", credentials=creds)

# %%
# Retorna uma tabela em formatação markdown com os textos em highlight, bem como suas respectivas páginas e comentários
def fichamento(pdf: fitz.Document):
    # Criar uma tabela com os textos em highlight, bem como suas respectivas páginas e comentários
    texto_highlight = []
    for numero_pagina in range(len(pdf)): # numero_pagina pode não ser o número real da página do PDF, dependendo de como está formatado
        pagina = pdf.load_page(numero_pagina)
        anotacoes = pagina.annots()
        if anotacoes:
            for annot in anotacoes:
                if annot.type[1] == 'Highlight':
                    caixa_conteudo = annot.rect
                    palavras = pagina.get_text("words")
                    # Conferir palavras que estão dentro do box de highlight
                    palavras_highlight = ""
                    for palavra in palavras:
                        caixa_palavra = fitz.Rect(palavra[:4])
                        if caixa_palavra.intersects(caixa_conteudo):
                            palavras_highlight += palavra[4] + " "

                    texto_highlight.append({
                        "Página do PDF": pagina.number + 1, # a primeira página é considerada 0, por isso somar +1 para saber a página correta do PDF
                        "Texto": palavras_highlight.strip(),
                        "Comentário": annot.info.get("content")
                    })
    return tabulate(texto_highlight, headers="keys", tablefmt="pipe")

# %%
# Retorna os arquivos ou pastas encontradas na pasta de ID id_pasta
def pesquisar_arquivos_pasta(id_pasta: str):
  arquivos = []

  query = f"'{id_pasta}' in parents"

  resposta_api = (
      servico_drive.files().list(
          q=query,
          fields="files(id, name, mimeType)",
          supportsAllDrives=True,
          includeItemsFromAllDrives=True
      ).execute()
  )

  for item in resposta_api.get("files", []):
    if item['mimeType'] == 'application/vnd.google-apps.folder':
      arquivos.extend(pesquisar_arquivos_pasta(item['id']))
    else:
      arquivos.append(item)

  return arquivos

# %%
arquivos = pesquisar_arquivos_pasta(drive_id)
if not arquivos:
  print("Nenhum arquivo encontrado na pasta do Drive.")
else:
  print(f"{len(arquivos)} arquivos encontrados.")
# Out:
# 42 arquivos encontrados.
# [{'id': '1a574WJlWFZ1maxs1jZ_bx9OvwJAqjajtDOr99MAXnqI', 'name': 'Fichamentos', 'mimeType': 'application/vnd.google-apps.document'}, {'id': '16XZxYcwkhGtRk9HfKgR4gwzsy2k789pP', 'name': 'fichamento.md', 'mimeType': 'text/markdown'}, {'id': '17O9U3ZxDSDMyrmOeiFPklZV2zoT2tjH5', 'name': 'OK SIMIÃO - Crise climática, mecanismos de mercado e a financeirização da natureza.pdf', 'mimeType': 'application/pdf'}, {'id': '13m9RuriGTVbDhXTRW_sNJ7sNopgE8thm', 'name': 'OK ZACARIAS - A lógica destrutiva do capital crise ambiental e mudanças climáticas.pdf', 'mimeType': 'application/pdf'}, {'id': '1haALoiEf2OV35O_zAJwJmss9MXdeNdyA', 'name': 'OK SILVA - Corpos antropofágicos - Supermáquina e interseccionalidades em cartoescrita de fluxos indisciplinares.pdf', 'mimeType': 'application/pdf'}, {'id': '1EzNGilYv6OCkAcz7Yu4q0PiadwH8XDl8', 'name': 'OK PEREIRA - Estudos Multiespécies.pdf', 'mimeType': 'application/pdf'}, {'id': '1BxXZHOmn3-3yhjFDTtxbJ0NhEiATGV3p', 'name': 'OK REIS - O especismo na mídia.pdf', 'mimeType': 'application/pdf'}, {'id': '1MjC3LRwyoduAZ5Eyj7VUV_BHXB9Eszja', 'name': 'OK DRESCHER - O especismo e o avanço mitigado na proteção dos animais no Brasil.pdf', 'mimeType': 'application/pdf'}, {'id': '1b5vTbt4JJ-O2M2X1i_EnntfXfeT7fA4z', 'name': 'OK FEITOSA - O especismo em sua realidade prática e mudanças pragmáticas geradas pela valoração à vida animal.pdf', 'mimeType': 'application/pdf'}, {'id': '1LCUpfoTqWtVtBAUDYNmOt9OLHdYJ6M5S', 'name': 'OK BRÜGGER - Especismo na TV.pdf', 'mimeType': 'application/pdf'}, {'id': '1_f71uMNFGdfuUqsyFLhIAFdxuWgNLeM5', 'name': 'OK SOARES - Especismo enquanto relação de exploração na construção do direito animal.pdf', 'mimeType': 'application/pdf'}, {'id': '1ZRjg495K8uKFuyMDi6Qp0a7QJlrZ1xRd', 'name': 'OK PAZZINI - A sonegação histórica de direitos animais e a construção do animal como não-sujeito.pdf', 'mimeType': 'application/pdf'}, {'id': '1qcA7EqourzkkVfkAeryz73rGAkJzCbh-', 'name': 'OK MELLO e DIAS - Por uma formação inventiva antiespecista.pdf', 'mimeType': 'application/pdf'}, {'id': '1en9k__7u6-p1b7ySA6ZL8P-tcy6_dpUg', 'name': 'OK PASQUALI - Antiespecismo abolicionismo e biocentrismo.pdf', 'mimeType': 'application/pdf'}, {'id': '1yJM6FlMR4m2HNt7cZCKt5jqFYB1eJ5Rk', 'name': 'OK BRÜGGER - O sacrifício animal em rituais religiosos.pdf', 'mimeType': 'application/pdf'}, {'id': '1JOHL1AD0v3MxZMWrC8PX3xyAbJRXJOSM', 'name': 'OK SCHÖPKE - Repensando o especismo.pdf', 'mimeType': 'application/pdf'}, {'id': '1k-OrSyyRuKwjVnmFVU-WY-fp-Nc4Ofbl', 'name': 'OK GODOY e SOUSA - Educação popular e movimentos antiespecistas.pdf', 'mimeType': 'application/pdf'}, {'id': '1MmdoNVcmokOt4w8FWxdZA310KDzWW8yj', 'name': 'OK BRÜGGER - O apocalipse da pecuária.pdf', 'mimeType': 'application/pdf'}, {'id': '190OY-jKW-yi83iC06-5aUQ9tYTnrofbt', 'name': 'OK ASSIS e PAIVA - Dialogando sobre especismo no ensino de biologia.pdf', 'mimeType': 'application/pdf'}, {'id': '18l9pmx-rutuazid_KpL9c4mT-qrNfBKb', 'name': 'OK ALBINO e SILVA - Especismo cegueira moral da sociedade.pdf', 'mimeType': 'application/pdf'}, {'id': '14gA0jqJb6TayVCm_I1VGL0ivNHCVZl2h', 'name': 'OK FRAGA - Mudanças socioambientais históricas e resultantes geo-hidroecológicas em áreas de manejo.PDF', 'mimeType': 'application/pdf'}, {'id': '1FGAi8j5Lx7-JH50fZt025Q0GRP4WxSoI', 'name': 'OK CAPANEMA por mais vidas na história.pdf', 'mimeType': 'application/pdf'}, {'id': '1zLD68eSskwINTfbvX6rCOZ6wxw_Xs6xV', 'name': 'OK NEDEL - Habitando as margens.pdf', 'mimeType': 'application/pdf'}, {'id': '12_qZhZ8VkadAD5crLgroaiXP_It5UlR1', 'name': 'OK VERGUEIRO SIMAKAWA - Por inflexoes decoloniais de corpos e identidades de genero inconformes.pdf', 'mimeType': 'application/pdf'}, {'id': '1TysT6lRxHpCxHPwiayYxjB2R0iRGEPgw', 'name': 'OK BONASSI - Cisnorma acordos societários sobre o sexo binário e cisgênero.pdf', 'mimeType': 'application/pdf'}, {'id': '1lhTLpT9-COnmqSgx66-jji2Dcla45T2X', 'name': 'OK PEREIRA - Entre corpos abjetos e zonas de monstruosidade.pdf', 'mimeType': 'application/pdf'}, {' ...

# %%
for arquivo in arquivos:
  if arquivo['mimeType'] == 'application/pdf':
    print(f"\tTentando baixar o {arquivo['name']}")

    # Baixar arquivo do Drive como I/O
    request = servico_drive.files().get_media(fileId=arquivo['id'])
    file = io.BytesIO()
    downloader = MediaIoBaseDownload(file, request)
    done = False
    while done is False:
      status, done = downloader.next_chunk()

      # Checar se o arquivo é um PDF válido e fazer o fichamento
      try:
        with fitz.open(stream=file, filetype="pdf") as pdf:
          print(f"\t\tArquivo válido como PDF, iniciando extração para fichamento...")
          tabela = fichamento(pdf)

          # Abrir o arquivo markdown para salvar o título e tabela
          try:
            with open("/content/fichamento.md", "a", encoding="utf-8") as output:
              titulo = ""
              # Essa regra confere se o nome do arquivo está na formatação "OK Autoria - Título.pdf"
              if arquivo['name'].startswith("OK "):
                titulo = arquivo['name'][3:-4]
              else:
                titulo = arquivo['name'][:-4]
              output.write(f"\n# {titulo} \n")
              output.write(tabela)
              print("\t\tSalvou com sucesso o fichamento desse PDF no arquivo markdown!")
          except Exception as error:
            print(f"\t\tOcorreu um erro na hora de salvar o fichamento, tente novamente")
            print(error)
      except Exception as error:
        print(f"\t\tPDF inválido: {arquivo['name']}")
        print(error)
# Out:
# 	Tentando baixar o OK SIMIÃO - Crise climática, mecanismos de mercado e a financeirização da natureza.pdf (17O9U3ZxDSDMyrmOeiFPklZV2zoT2tjH5)
# 		O OK SIMIÃO - Crise climática, mecanismos de mercado e a financeirização da natureza.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK ZACARIAS - A lógica destrutiva do capital crise ambiental e mudanças climáticas.pdf (13m9RuriGTVbDhXTRW_sNJ7sNopgE8thm)
# 		O OK ZACARIAS - A lógica destrutiva do capital crise ambiental e mudanças climáticas.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK SILVA - Corpos antropofágicos - Supermáquina e interseccionalidades em cartoescrita de fluxos indisciplinares.pdf (1haALoiEf2OV35O_zAJwJmss9MXdeNdyA)
# 		O OK SILVA - Corpos antropofágicos - Supermáquina e interseccionalidades em cartoescrita de fluxos indisciplinares.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK PEREIRA - Estudos Multiespécies.pdf (1EzNGilYv6OCkAcz7Yu4q0PiadwH8XDl8)
# 		O OK PEREIRA - Estudos Multiespécies.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK REIS - O especismo na mídia.pdf (1BxXZHOmn3-3yhjFDTtxbJ0NhEiATGV3p)
# 		O OK REIS - O especismo na mídia.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK DRESCHER - O especismo e o avanço mitigado na proteção dos animais no Brasil.pdf (1MjC3LRwyoduAZ5Eyj7VUV_BHXB9Eszja)
# 		O OK DRESCHER - O especismo e o avanço mitigado na proteção dos animais no Brasil.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK FEITOSA - O especismo em sua realidade prática e mudanças pragmáticas geradas pela valoração à vida animal.pdf (1b5vTbt4JJ-O2M2X1i_EnntfXfeT7fA4z)
# 		O OK FEITOSA - O especismo em sua realidade prática e mudanças pragmáticas geradas pela valoração à vida animal.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK BRÜGGER - Especismo na TV.pdf (1LCUpfoTqWtVtBAUDYNmOt9OLHdYJ6M5S)
# 		O OK BRÜGGER - Especismo na TV.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK SOARES - Especismo enquanto relação de exploração na construção do direito animal.pdf (1_f71uMNFGdfuUqsyFLhIAFdxuWgNLeM5)
# 		O OK SOARES - Especismo enquanto relação de exploração na construção do direito animal.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK PAZZINI - A sonegação histórica de direitos animais e a construção do animal como não-sujeito.pdf (1ZRjg495K8uKFuyMDi6Qp0a7QJlrZ1xRd)
# 		O OK PAZZINI - A sonegação histórica de direitos animais e a construção do animal como não-sujeito.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK MELLO e DIAS - Por uma formação inventiva antiespecista.pdf (1qcA7EqourzkkVfkAeryz73rGAkJzCbh-)
# 		O OK MELLO e DIAS - Por uma formação inventiva antiespecista.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK PASQUALI - Antiespecismo abolicionismo e biocentrismo.pdf (1en9k__7u6-p1b7ySA6ZL8P-tcy6_dpUg)
# 		O OK PASQUALI - Antiespecismo abolicionismo e biocentrismo.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK BRÜGGER - O sacrifício animal em rituais religiosos.pdf (1yJM6FlMR4m2HNt7cZCKt5jqFYB1eJ5Rk)
# 		O OK BRÜGGER - O sacrifício animal em rituais religiosos.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK SCHÖPKE - Repensando o especismo.pdf (1JOHL1AD0v3MxZMWrC8PX3xyAbJRXJOSM)
# 		O OK SCHÖPKE - Repensando o especismo.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK GODOY e SOUSA - Educação popular e movimentos antiespecistas.pdf (1k-OrSyyRuKwjVnmFVU-WY-fp-Nc4Ofbl)
# 		O OK GODOY e SOUSA - Educação popular e movimentos antiespecistas.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK BRÜGGER - O apocalipse da pecuária.pdf (1MmdoNVcmokOt4w8FWxdZA310KDzWW8yj)
# 		O OK BRÜGGER - O apocalipse da pecuária.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK ASSIS e PAIVA - Dialogando sobre especismo no ensino de biologia.pdf (190OY-jKW-yi83iC06-5aUQ9tYTnrofbt)
# 		O OK ASSIS e PAIVA - Dialogando sobre especismo no ensino de biologia.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK ALBINO e SILVA - Especismo cegueira moral da sociedade.pdf (18l9pmx-rutuazid_KpL9c4mT-qrNfBKb)
# 		O OK ALBINO e SILVA - Especismo cegueira moral da sociedade.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK FRAGA - Mudanças socioambientais históricas e resultantes geo-hidroecológicas em áreas de manejo.PDF (14gA0jqJb6TayVCm_I1VGL0ivNHCVZl2h)
# 		O OK FRAGA - Mudanças socioambientais históricas e resultantes geo-hidroecológicas em áreas de manejo.PDF é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK CAPANEMA por mais vidas na história.pdf (1FGAi8j5Lx7-JH50fZt025Q0GRP4WxSoI)
# 		O OK CAPANEMA por mais vidas na história.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK NEDEL - Habitando as margens.pdf (1zLD68eSskwINTfbvX6rCOZ6wxw_Xs6xV)
# 		O OK NEDEL - Habitando as margens.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK VERGUEIRO SIMAKAWA - Por inflexoes decoloniais de corpos e identidades de genero inconformes.pdf (12_qZhZ8VkadAD5crLgroaiXP_It5UlR1)
# 		O OK VERGUEIRO SIMAKAWA - Por inflexoes decoloniais de corpos e identidades de genero inconformes.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK BONASSI - Cisnorma acordos societários sobre o sexo binário e cisgênero.pdf (1TysT6lRxHpCxHPwiayYxjB2R0iRGEPgw)
# 		O OK BONASSI - Cisnorma acordos societários sobre o sexo binário e cisgênero.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK PEREIRA - Entre corpos abjetos e zonas de monstruosidade.pdf (1lhTLpT9-COnmqSgx66-jji2Dcla45T2X)
# 		O OK PEREIRA - Entre corpos abjetos e zonas de monstruosidade.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK PEREIRA - Teoria do elo.pdf (1HUvC_48fA_sD4YWtaTKxSAc_fBnQuFqD)
# 		O OK PEREIRA - Teoria do elo.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK JESUS - Transfobia e crimes de ódio.pdf (1oRBX_KoLrENrey3rCIhdJgKAauPKP8FO)
# 		O OK JESUS - Transfobia e crimes de ódio.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK NEDEL - O corpo como arquivo.pdf (1MaBNtw6vBTYYeQ1GIooJJk2l5Wd0bj_O)
# 		O OK NEDEL - O corpo como arquivo.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK NEDEL e GUIMARÃES - Habitando as margens.pdf (15QK8CSEmVexMtUxLeKg_l3nOqGjCRux_)
# 		O OK NEDEL e GUIMARÃES - Habitando as margens.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK VIANA - De menino a sujeito homem.pdf (1FmlWpGwn_r8RC2fnP06rqFVLi77YC1p4)
# 		O OK VIANA - De menino a sujeito homem.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK LEONARDO ATHAYDE e POCAHY - O conceito de cisgeneridade e a produção de deslocamentos nas políticas feministas contemporâneas.pdf (1j4RQE6YokXVHgGdjrE-jmHFzSnN0BNr1)
# 		O OK LEONARDO ATHAYDE e POCAHY - O conceito de cisgeneridade e a produção de deslocamentos nas políticas feministas contemporâneas.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK JESUS - O conceito de heterocentrismo.pdf (1eqSl7atHzGRZBtjZylmJi3upJl2PgHS8)
# 		O OK JESUS - O conceito de heterocentrismo.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK VIEIRA - Transfeminicídio no Brasil.pdf (1kAiD1S4h0dhxSjG7cm-zSjMpZSQrTRax)
# 		O OK VIEIRA - Transfeminicídio no Brasil.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK TEDESCO - Não se nasce homem torna-se.pdf (1-cyZ0sP5AOT015W2rx9GkxdIIG9FQfWZ)
# 		O OK TEDESCO - Não se nasce homem torna-se.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK MARIN e PAGAN - Entrevista Alice Alexandre Pagan.pdf (15Q2nmAFu5daPpDX7IK9kRXOwPrBEFMAj)
# 		O OK MARIN e PAGAN - Entrevista Alice Alexandre Pagan.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK BRANDÃO - Literatura e ecologia vozes feministas e interseccionais.pdf (1b1tJcsOpsS5LwhWnyjIeKq8B2FO57jmt)
# 		O OK BRANDÃO - Literatura e ecologia vozes feministas e interseccionais.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK SANTOS - Os brancos não falam a verdade contra mim. Por que ele é homem e não havia de passar o trabalho das fêmeas.pdf (1neWZG2qiI4fAfgBLisuOHYoQx2tgIkY9)
# 		O OK SANTOS - Os brancos não falam a verdade contra mim. Por que ele é homem e não havia de passar o trabalho das fêmeas.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK NÚÑEZ OLIVEIRA e LAGO - Monogamia e anticolonialidades.pdf (1EhUAgQomqXhjzdiL99D9MAvaC0jLQ8s2)
# 		O OK NÚÑEZ OLIVEIRA e LAGO - Monogamia e anticolonialidades.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK NÚÑEZ - Monoculturas do pensamento e a importância do reflorestamento do imaginário.pdf (1NCKw_T88gDRUix7soRxFGK4MKO9mLYwa)
# 		O OK NÚÑEZ - Monoculturas do pensamento e a importância do reflorestamento do imaginário.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK CARVALHO KANHGÁG - Kanhgang êg my há para uma psicologia kaingang.pdf (1PRJRA-4-2TzUZrE9vjrrcY7T2uiHtLu4)
# 		O OK CARVALHO KANHGÁG - Kanhgang êg my há para uma psicologia kaingang.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!
# 	Tentando baixar o OK NÚÑEZ - Nhande ayvu é da cor da terra.pdf (1KX5V7_ovwb7vZHEiiUbDu0pF0gXsSVj4)
# 		O OK NÚÑEZ - Nhande ayvu é da cor da terra.pdf é válido como PDF, iniciando extração para fichamento...
# 		Salvou com sucesso o fichamento no arquivo markdown!

# %% [markdown]
# No próximo passo, o arquivo **fichamento.md** que está localmente salvo na seção "Arquivos" (ver ícone de pasta no menu lateral esquerdo), será importado já em formato Google Docs na pasta informada anteriormente.

# %%
# Salvar o arquivo markdown dos fichamentos no Google Drive
metadados_markdown = {
    "name": "Fichamentos - Ferramenta de extração de PDF",
    "mimeType": "application/vnd.google-apps.documents",
    "parents": [
        f"{drive_id}"
        ]
    }
midia_markdown = MediaFileUpload("/content/fichamento.md", mimetype="text/markdown")
upload_arquivo_fichamento = servico_drive.files().create(
    body=metadados_markdown,
    media_body=midia_markdown,
    supportsAllDrives=True,
    fields="id"
    ).execute()

print(f'Fichamento salvo no Google Drive: {upload_arquivo_fichamento.get("id")} ! Boa escrita!')
# Out:
# Fichamento salvo no Google Drive: 1dJFVHehVFEv52kOuqINKyesFg1ScGBPCoricHLR6qbI
